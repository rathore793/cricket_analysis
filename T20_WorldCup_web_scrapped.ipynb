# %%
#Importing Required Libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time

# %%
#Setting Options for Selenium Webdriver
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')

# %%
#Base Url is main page of the website we need to scrape
base_url = "https://www.espncricinfo.com/records/season/team-match-results/2022to23-2022to23?trophy=89"

# %%
# this function will check whether the player image is available and if yes return its url
def player_image(driver):
    try:
        player_image = driver.find_element(By.XPATH, '//*[@id="main-container"]/div[5]/div[1]/div[2]/div[1]/div[1]/div/div/div/div[1]/div/div[2]/div/div/img')
    except NoSuchElementException:
        return 'nan'
    else:
        return player_image.get_attribute('src')

# %%
#this function will give all the credentials of the player, including bowling and batting style
def get_profile(driver):
    image_url = player_image(driver)
    team =  driver.find_element(By.XPATH, '//*[@id="main-container"]/div[5]/div[1]/div[2]/div[2]/div[2]/div/div/div[2]/div/a[1]/span/span').text
    name = driver.find_element(By.XPATH, '//*[@id="main-container"]/div[5]/div[1]/div[2]/div[1]/div[1]/div/div/div/div[1]/div/div[1]/h1').text
    skills = driver.find_elements(By.XPATH, '//*[@id="main-container"]/div[5]/div[1]/div[2]/div[2]/div[2]/div/div/div[1]')
    skill_entries = skills[0].text.split('\n')[::2]
    skill_values = skills[0].text.split('\n')[1::2]
    bating = 'nan'
    bowling = 'nan'
    role = 'nan'
    for i in range(len(skill_entries)):
        if skill_entries[i] == "BATTING STYLE":
            bating = skill_values[i] 
        elif skill_entries[i] == "BOWLING STYLE":
            bowling = skill_values[i] 
        elif skill_entries[i] == "PLAYING ROLE":
            role = skill_values[i]
    driver.quit()
    return name, team, bating, bowling, role, image_url

# %%
#this function will open the player profile in selenium and check for pop-up and proceed basis the outcome
def player_profile(url):
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    time.sleep(15)
    try:
        pop_up =driver.find_element(By.CSS_SELECTOR, 'button#wzrk-cancel')
    except NoSuchElementException:
        return get_profile(driver)
    else:
        pop_up.click()
        time.sleep(1)
        return get_profile(driver)

# %%
#get_content will give the html page data of the website
def get_content(url):
    response = requests.get(url)
    # if status code is other than 200 the process will not move further
    if response.status_code == 200:
        return BeautifulSoup(response.text, 'html.parser')
    else:
        print(f"The URL {url} is invalid")

# %%
#match url is the web address of any particular match, match data will provide all the summary of the match
def match_data(match_url):
    match_content = get_content(match_url)
    #team between which the match is going
    teams = match_content.find_all('span', {"class": "ds-text-title-xs ds-font-bold ds-capitalize"})
    team1 = teams[0].text
    team2 = teams[1].text
    #match_summary content the whole score card of the match for both the innings, we use 'tbody' as the selector for selecting this part of the website
    match_summary = match_content.find_all('tbody')[:4]
    
    match = f"{team1} Vs {team2}"
    
    #Inning list arranged in a way how the team going to bat and bowl in order
    innings = [team1, team2, team2, team1]
    
    #looping in match_summary so the we can extract data from each part(batting and bowling from both side)
    for i in range(len(match_summary)):  
        if i % 2 == 0:
            #Batting Inning
            bat_pos = 1
            for player in match_summary[i]: 
                if player.contents[0].text.strip().lower() == 'extras' or player.contents[0].text.strip().lower() == 'total':
                    break
                else:
                    # Using try and except block as it have hidden tag which have value which is unrelated to our data
                    try:
                        int(player.text[0])
                    except ValueError:
                        batting_dict['match'].append(match)
                        batting_dict['team_inning'].append(innings[i])
                        batting_dict['batting_pos'].append(bat_pos)
                        batting_dict['player_name'].append(player.contents[0].text.strip())
                        batting_dict['player_profile'].append(f"https://www.espncricinfo.com{player.contents[0].a['href']}")
                        player_profile_dict['profile_url'].append(f"https://www.espncricinfo.com{player.contents[0].a['href']}")
                        batting_dict['out/not_out'].append(player.contents[1].text)
                        batting_dict['run'].append(player.contents[2].text)
                        batting_dict['balls'].append(player.contents[3].text)
                        batting_dict['maiden'].append(player.contents[4].text)
                        batting_dict['4s'].append(player.contents[5].text)
                        batting_dict['6s'].append(player.contents[6].text)
                        batting_dict['strike_rate'].append(player.contents[7].text)
                        player.contents[0].text
                        bat_pos += 1
                    except IndexError:
                        continue
        else:
            #Bowling Inning
            for bowler in match_summary[i]:
                try:
                    int(bowler.text[0])
                except ValueError:     
                    bowling_dict['match'].append(match)
                    bowling_dict['bowling_team'].append(innings[i])
                    bowling_dict['bowler'].append(bowler.contents[0].text.strip())
                    bowling_dict['bowler_profile'].append(f"https://www.espncricinfo.com{bowler.contents[0].a['href']}")
                    player_profile_dict['profile_url'].append(f"https://www.espncricinfo.com{bowler.contents[0].a['href']}")
                    bowling_dict['over'].append(bowler.contents[1].text)
                    bowling_dict['maiden'].append(bowler.contents[2].text)
                    bowling_dict['runs'].append(bowler.contents[3].text)
                    bowling_dict['wickets'].append(bowler.contents[4].text)
                    bowling_dict['economy'].append(bowler.contents[5].text)
                    bowling_dict['0s'].append(bowler.contents[6].text)
                    bowling_dict['4s'].append(bowler.contents[7].text)
                    bowling_dict['6s'].append(bowler.contents[8].text)
                    bowling_dict['wides'].append(bowler.contents[9].text)
                    bowling_dict['no_balls'].append(bowler.contents[10].text)

# %%
all_match_content = get_content(base_url)

# %%
matches = {"Team1":[], "Team2":[], "Winner":[], "Margin":[], "Ground":[], "Date":[],"Match_id":[], "URL":[],}
for item in all_match_content.find_all('tr'):
    matches['Team1'].append(item.contents[0].text)
    matches['Team2'].append(item.contents[1].text)
    matches['Winner'].append(item.contents[2].text)
    matches['Margin'].append(item.contents[3].text)
    matches['Ground'].append(item.contents[4].text)
    matches['Date'].append(item.contents[5].text)
    if item.contents[6].text != 'Scorecard':
        matches['Match_id'].append(item.contents[6].text)
        matches['URL'].append(f"https://www.espncricinfo.com{item.contents[6].a['href']}")
    else:
        matches['Match_id'].append('NA')
        matches['URL'].append('NA')

# %%
# Making dataframe from mathces dictionary
all_matches_df =pd.DataFrame(matches)

# %%
# Dropping the first row
all_matches_df.drop(0, axis=0, inplace=True)

# %%
all_matches_df
# Out:
#            Team1         Team2        Winner      Margin     Ground  \
# 1        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 2    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 3       Scotland   West Indies      Scotland     42 runs     Hobart
# 4        Ireland      Zimbabwe      Zimbabwe     31 runs     Hobart
# 5        Namibia   Netherlands   Netherlands   5 wickets    Geelong
# 6      Sri Lanka        U.A.E.     Sri Lanka     79 runs    Geelong
# 7        Ireland      Scotland       Ireland   6 wickets     Hobart
# 8    West Indies      Zimbabwe   West Indies     31 runs     Hobart
# 9    Netherlands     Sri Lanka     Sri Lanka     16 runs    Geelong
# 10       Namibia        U.A.E.        U.A.E.      7 runs    Geelong
# 11       Ireland   West Indies       Ireland   9 wickets     Hobart
# 12      Scotland      Zimbabwe      Zimbabwe   5 wickets     Hobart
# 13     Australia   New Zealand   New Zealand     89 runs     Sydney
# 14   Afghanistan       England       England   5 wickets      Perth
# 15       Ireland     Sri Lanka     Sri Lanka   9 wickets     Hobart
# 16         India      Pakistan         India   4 wickets  Melbourne
# 17    Bangladesh   Netherlands    Bangladesh      9 runs     Hobart
# 18  South Africa      Zimbabwe     no result           -     Hobart
# 19     Australia     Sri Lanka     Australia   7 wickets      Perth
# 20       England       Ireland       Ireland      5 runs  Melbourne
# 21    Bangladesh  South Africa  South Africa    104 runs     Sydney
# 22         India   Netherlands         India     56 runs     Sydney
# 23      Pakistan      Zimbabwe      Zimbabwe       1 run      Perth
# 24   New Zealand     Sri Lanka   New Zealand     65 runs     Sydney
# 25    Bangladesh      Zimbabwe    Bangladesh      3 runs   Brisbane
# 26   Netherlands      Pakistan      Pakistan   6 wickets      Perth
# 27         India  South Africa  South Africa   5 wickets      Perth
# 28     Australia       Ireland     Australia     42 runs   Brisbane
# 29   Afghanistan     Sri Lanka     Sri Lanka   6 wickets   Brisbane
# 30       England   New Zealand       England     20 runs   Brisbane
# 31   Netherlands      Zimbabwe   Netherlands   5 wickets   Adelaide
# 32    Bangladesh         India         India      5 runs   Adelaide
# 33      Pakistan  South Africa      Pakistan     33 runs     Sydney
# 34       Ireland   New Zealand   New Zealand     35 runs   Adelaide
# 35     Australia   Afghanistan     Australia      4 runs   Adelaide
# 36       England     Sri Lanka       England   4 wickets     Sydney
# 37   Netherlands  South Africa   Netherlands     13 runs   Adelaide
# 38    Bangladesh      Pakistan      Pakistan   5 wickets   Adelaide
# 39         India      Zimbabwe         India     71 runs  Melbourne
# 40   New Zealand      Pakistan      Pakistan   7 wickets     Sydney
# 41       England         India       England  10 wickets   Adelaide
# 42       England      Pakistan       England   5 wickets  Melbourne
#
#             Date     Match_id  \
# 1   Oct 16, 2022  T20I # 1823
# 2   Oct 16, 2022  T20I # 1825
# 3   Oct 17, 2022  T20I # 1826
# 4   Oct 17, 2022  T20I # 1828
# 5   Oct 18, 2022  T20I # 1830
# 6   Oct 18, 2022  T20I # 1832
# 7   Oct 19, 2022  T20I # 1833
# 8   Oct 19, 2022  T20I # 1834
# 9   Oct 20, 2022  T20I # 1835
# 10  Oct 20, 2022  T20I # 1836
# 11  Oct 21, 2022  T20I # 1837
# 12  Oct 21, 2022  T20I # 1838
# 13  Oct 22, 2022  T20I # 1839
# 14  Oct 22, 2022  T20I # 1840
# 15  Oct 23, 2022  T20I # 1841
# 16  Oct 23, 2022  T20I # 1842
# 17  Oct 24, 2022  T20I # 1843
# 18  Oct 24, 2022  T20I # 1844
# 19  Oct 25, 2022  T20I # 1845
# 20  Oct 26, 2022  T20I # 1846
# 21  Oct 27, 2022  T20I # 1847
# 22  Oct 27, 2022  T20I # 1848
# 23  Oct 27, 2022  T20I # 1849
# 24  Oct 29, 2022  T20I # 1850
# 25  Oct 30, 2022  T20I # 1851
# 26  Oct 30, 2022  T20I # 1852
# 27  Oct 30, 2022  T20I # 1853
# 28  Oct 31, 2022  T20I # 1855
# 29   Nov 1, 2022  T20I # 1856
# 30   Nov 1, 2022  T20I # 1858
# 31   Nov 2, 2022  T20I # 1859
# 32   Nov 2, 2022  T20I # 1860
# 33   Nov 3, 2022  T20I # 1861
# 34   Nov 4, 2022  T20I # 1862
# 35   Nov 4, 2022  T20I # 1864
# 36   Nov 5, 2022  T20I # 1867
# 37   Nov 6, 2022  T20I # 1871
# 38   Nov 6, 2022  T20I # 1872
# 39   Nov 6, 2022  T20I # 1873
# 40   Nov 9, 2022  T20I # 1877
# 41  Nov 10, 2022  T20I # 1878
# 42  Nov 13, 2022  T20I # 1879
#
#                                                   URL
# 1   https://www.espncricinfo.com/series/icc-men-s-...
# 2   https://www.espncricinfo.com/series/icc-men-s-...
# 3   https://www.espncricinfo.com/series/icc-men-s-...
# 4   https://www.espncricinfo.com/series/icc-men-s-...
# 5   https://www.espncricinfo.com/series/icc-men-s-...
# 6   https://www.espncricinfo.com/series/icc-men-s-...
# 7   https://www.espncricinfo.com/series/icc-men-s-...
# 8   https://www.espncricinfo.com/series/icc-men-s-...
# 9   https://www.espncricinfo.com/series/icc-men-s-...
# 10  https://www.espncricinfo.com/series/icc-men-s-...
# 11  https://www.espncricinfo.com/series/icc-men-s-...
# 12  https://www.espncricinfo.com/series/icc-men-s-...
# 13  https://www.espncricinfo.com/series/icc-men-s-...
# 14  https://www.espncricinfo.com/series/icc-men-s-...
# 15  https://www.espncricinfo.com/series/icc-men-s-...
# 16  https://www.espncricinfo.com/series/icc-men-s-...
# 17  https://www.espncricinfo.com/series/icc-men-s-...
# 18  https://www.espncricinfo.com/series/icc-men-s-...
# 19  https://www.espncricinfo.com/series/icc-men-s-...
# 20  https://www.espncricinfo.com/series/icc-men-s-...
# 21  https://www.espncricinfo.com/series/icc-men-s-...
# 22  https://www.espncricinfo.com/series/icc-men-s-...
# 23  https://www.espncricinfo.com/series/icc-men-s-...
# 24  https://www.espncricinfo.com/series/icc-men-s-...
# 25  https://www.espncricinfo.com/series/icc-men-s-...
# 26  https://www.espncricinfo.com/series/icc-men-s-...
# 27  https://www.espncricinfo.com/series/icc-men-s-...
# 28  https://www.espncricinfo.com/series/icc-men-s-...
# 29  https://www.espncricinfo.com/series/icc-men-s-...
# 30  https://www.espncricinfo.com/series/icc-men-s-...
# 31  https://www.espncricinfo.com/series/icc-men-s-...
# 32  https://www.espncricinfo.com/series/icc-men-s-...
# 33  https://www.espncricinfo.com/series/icc-men-s-...
# 34  https://www.espncricinfo.com/series/icc-men-s-...
# 35  https://www.espncricinfo.com/series/icc-men-s-...
# 36  https://www.espncricinfo.com/series/icc-men-s-...
# 37  https://www.espncricinfo.com/series/icc-men-s-...
# 38  https://www.espncricinfo.com/series/icc-men-s-...
# 39  https://www.espncricinfo.com/series/icc-men-s-...
# 40  https://www.espncricinfo.com/series/icc-men-s-...
# 41  https://www.espncricinfo.com/series/icc-men-s-...
# 42  https://www.espncricinfo.com/series/icc-men-s-...

# %%
# Empty Dictionary for the data which needed to be fetched
batting_dict = {'match': [], 'team_inning': [], 'batting_pos': [], 'player_name': [], 'player_profile': [], 'out/not_out': [],'run': [], 'balls': [], 'maiden': [], '4s': [], '6s': [], 'strike_rate': [],}

bowling_dict = {'match': [], 'bowling_team': [], 'bowler': [], 'bowler_profile': [], 'over': [], 'maiden': [], 'runs': [], 'wickets': [], 'economy': [], '0s': [], '4s': [], '6s': [], 'wides': [], 'no_balls': [] }

player_profile_dict = {'name': [], 'team': [], 'batting_style': [], 'bowling_style': [], 'playing_role': [], 'profile_url':[], 'profile_image' : [] }

# %%
# Looping in all_matches_df dataframe to get the url for all the matches, so that their content can be fetched using get_content function and data using match_data function
for index, row in all_matches_df.iterrows():
    match_data(row['URL'])

# %%
# player profile dictionary get the profile url using match_data function, we can get these url to be used with player_profile function to get their data
# Removing all the duplicates

player_profile_dict['profile_url'] = list(set(player_profile_dict['profile_url']))
for url in player_profile_dict['profile_url']:
    player_tuple = player_profile(url)
    time.sleep(2)
    #getting all the information from tuple to palyer dictionary
    player_profile_dict['name'].append(player_tuple[0])
    player_profile_dict['team'].append(player_tuple[1])
    player_profile_dict['batting_style'].append(player_tuple[2])
    player_profile_dict['bowling_style'].append(player_tuple[3])
    player_profile_dict['playing_role'].append(player_tuple[4])
    player_profile_dict['profile_image'].append(player_tuple[5])

# %%
# Batting Data Data}frame
batting_df = pd.DataFrame(batting_dict)
batting_df
# Out:
#                     match team_inning  batting_pos             player_name  \
# 0    Namibia Vs Sri Lanka     Namibia            1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia            2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia            3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia            4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia            5     Gerhard Erasmus (c)
# ..                    ...         ...          ...                     ...
# 694   Pakistan Vs England     England            3               Phil Salt
# 695   Pakistan Vs England     England            4              Ben Stokes
# 696   Pakistan Vs England     England            5             Harry Brook
# 697   Pakistan Vs England     England            6               Moeen Ali
# 698   Pakistan Vs England     England            7        Liam Livingstone
#
#                                         player_profile  \
# 0    https://www.espncricinfo.com/cricketers/michae...
# 1    https://www.espncricinfo.com/cricketers/divan-...
# 2    https://www.espncricinfo.com/cricketers/jan-ni...
# 3    https://www.espncricinfo.com/cricketers/stepha...
# 4    https://www.espncricinfo.com/cricketers/gerhar...
# ..                                                 ...
# 694  https://www.espncricinfo.com/cricketers/phil-s...
# 695  https://www.espncricinfo.com/cricketers/ben-st...
# 696  https://www.espncricinfo.com/cricketers/harry-...
# 697  https://www.espncricinfo.com/cricketers/moeen-...
# 698  https://www.espncricinfo.com/cricketers/liam-l...
#
#                              out/not_out run balls maiden 4s 6s strike_rate
# 0           c Pramod Madushan b Chameera   3     6      7  0  0       50.00
# 1            c Shanaka b Pramod Madushan   9     9     15  1  0      100.00
# 2                c †Mendis b Karunaratne  20    12     18  1  2      166.66
# 3        c DM de Silva b Pramod Madushan  26    24     49  2  0      108.33
# 4           c Gunathilaka b PWH de Silva  20    24     30  0  0       83.33
# ..                                   ...  ..   ...    ... .. ..         ...
# 694        c Iftikhar Ahmed b Haris Rauf  10     9     16  2  0      111.11
# 695                             not out   52    49     81  5  1      106.12
# 696  c Shaheen Shah Afridi b Shadab Khan  20    23     36  1  0       86.95
# 697                     b Mohammad Wasim  19    13     30  3  0      146.15
# 698                             not out    1     1      3  0  0      100.00
#
# [699 rows x 12 columns]

# %%
# Bowling Data Dataframe
bowling_df = pd.DataFrame(bowling_dict)
bowling_df
# Out:
#                     match bowling_team               bowler  \
# 0    Namibia Vs Sri Lanka    Sri Lanka   Maheesh Theekshana
# 1    Namibia Vs Sri Lanka    Sri Lanka  Dushmantha Chameera
# 2    Namibia Vs Sri Lanka    Sri Lanka      Pramod Madushan
# 3    Namibia Vs Sri Lanka    Sri Lanka  Chamika Karunaratne
# 4    Namibia Vs Sri Lanka    Sri Lanka    Wanindu Hasaranga
# ..                    ...          ...                  ...
# 495   Pakistan Vs England     Pakistan          Naseem Shah
# 496   Pakistan Vs England     Pakistan           Haris Rauf
# 497   Pakistan Vs England     Pakistan          Shadab Khan
# 498   Pakistan Vs England     Pakistan       Mohammad Wasim
# 499   Pakistan Vs England     Pakistan       Iftikhar Ahmed
#
#                                         bowler_profile over maiden runs  \
# 0    https://www.espncricinfo.com/cricketers/mahees...    4      0   23
# 1    https://www.espncricinfo.com/cricketers/dushma...    4      0   39
# 2    https://www.espncricinfo.com/cricketers/pramod...    4      0   37
# 3    https://www.espncricinfo.com/cricketers/chamik...    4      0   36
# 4    https://www.espncricinfo.com/cricketers/wanind...    4      0   27
# ..                                                 ...  ...    ...  ...
# 495  https://www.espncricinfo.com/cricketers/naseem...    4      0   30
# 496  https://www.espncricinfo.com/cricketers/haris-...    4      0   23
# 497  https://www.espncricinfo.com/cricketers/shadab...    4      0   20
# 498  https://www.espncricinfo.com/cricketers/mohamm...    4      0   38
# 499  https://www.espncricinfo.com/cricketers/iftikh...  0.5      0   13
#
#     wickets economy  0s 4s 6s wides no_balls
# 0         1    5.75   7  0  0     2        0
# 1         1    9.75   6  3  1     2        0
# 2         2    9.25   6  3  1     0        0
# 3         1    9.00   7  3  1     1        0
# 4         1    6.75   8  1  1     0        0
# ..      ...     ...  .. .. ..   ...      ...
# 495       0    7.50  15  3  1     1        0
# 496       2    5.75  13  3  0     1        0
# 497       1    5.00  10  1  0     0        0
# 498       1    9.50   5  5  0     2        0
# 499       0   15.60   0  1  1     0        0
#
# [500 rows x 14 columns]

# %%
# Player Profile Data Dataframe
player_df = pd.DataFrame(player_profile_dict)
player_df
# Out:
#                  name         team   batting_style  \
# 0          Simi Singh      Ireland  Right hand Bat
# 1    Mosaddek Hossain   Bangladesh  Right hand Bat
# 2         Tim Southee  New Zealand  Right hand Bat
# 3          Mark Adair      Ireland  Right hand Bat
# 4          Axar Patel        India   Left hand Bat
# ..                ...          ...             ...
# 208        Fionn Hand      Ireland  Right hand Bat
# 209    Barry McCarthy      Ireland  Right hand Bat
# 210     Gareth Delany      Ireland  Right hand Bat
# 211     James Neesham  New Zealand   Left hand Bat
# 212     Paul Stirling      Ireland  Right hand Bat
#
#                            bowling_style         playing_role  \
# 0    Right arm Offbreak, Legbreak Googly   Bowling Allrounder
# 1                     Right arm Offbreak  Middle order Batter
# 2                  Right arm Medium fast               Bowler
# 3                  Right arm Fast medium   Bowling Allrounder
# 4                 Slow Left arm Orthodox   Bowling Allrounder
# ..                                   ...                  ...
# 208                     Right arm Medium   Bowling Allrounder
# 209                Right arm Fast medium               Bowler
# 210                      Legbreak Googly   Batting Allrounder
# 211                Right arm Medium fast   Batting Allrounder
# 212                   Right arm Offbreak   Batting Allrounder
#
#                                            profile_url  \
# 0    https://www.espncricinfo.com/cricketers/simi-s...
# 1    https://www.espncricinfo.com/cricketers/mosadd...
# 2    https://www.espncricinfo.com/cricketers/tim-so...
# 3    https://www.espncricinfo.com/cricketers/mark-a...
# 4    https://www.espncricinfo.com/cricketers/axar-p...
# ..                                                 ...
# 208  https://www.espncricinfo.com/cricketers/fionn-...
# 209  https://www.espncricinfo.com/cricketers/barry-...
# 210  https://www.espncricinfo.com/cricketers/gareth...
# 211  https://www.espncricinfo.com/cricketers/james-...
# 212  https://www.espncricinfo.com/cricketers/paul-s...
#
#                                          profile_image
# 0    https://img1.hscicdn.com/image/upload/f_auto,t...
# 1    https://img1.hscicdn.com/image/upload/f_auto,t...
# 2    https://img1.hscicdn.com/image/upload/f_auto,t...
# 3    https://img1.hscicdn.com/image/upload/f_auto,t...
# 4    https://img1.hscicdn.com/image/upload/f_auto,t...
# ..                                                 ...
# 208  https://img1.hscicdn.com/image/upload/f_auto,t...
# 209  https://img1.hscicdn.com/image/upload/f_auto,t...
# 210  https://img1.hscicdn.com/image/upload/f_auto,t...
# 211  https://img1.hscicdn.com/image/upload/f_auto,t...
# 212  https://img1.hscicdn.com/image/upload/f_auto,t...
#
# [213 rows x 7 columns]

# %%
# Saving all the datafram into csv files.
all_matches_df.to_csv('data/matches_data.csv')
batting_df.to_csv('data/batting_data.csv')
bowling_df.to_csv('data/bowling_data.csv')
player_df.to_csv('data/players_data.csv')
